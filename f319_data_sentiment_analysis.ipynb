# %% [markdown]
# ## F319 Posts Aggregation

# %%
import pandas as pd
import re
from tqdm import tqdm
import os

# Regex pattern to remove everything from "XYZ đã viết:" to "xem tất cả"
reply_block_pattern = re.compile(r".*? đã viết:.*?xem tất cả\.?", flags=re.DOTALL | re.IGNORECASE)

def clean_reply(text):
    if not text or not isinstance(text, str):
        return text

    # Find the start of the quoted reply
    start_idx = text.find(" đã viết:")
    if start_idx == -1:
        return text.strip()  # no reply block, keep text

    # Find the end of "xem tất cả"
    end_idx = text.lower().find("xem tất cả", start_idx)
    if end_idx == -1:
        return text[:start_idx].strip()  # cut everything from start_idx to end
    else:
        return text[end_idx + len("xem tất cả"):].strip()

def preprocess_f319_posts(file_paths, output_path='f319_data/aggregated_f319_data/aggregated_f319_posts.csv'):
    """
    Preprocess F319 posts using pandas:
    - Reads multiple CSV files
    - Converts post_time to datetime
    - Removes quoted reply blocks ("XYZ đã viết:\n... Xem tất cả")
    - Keeps one row per post
    - Filters out posts before 2020-01-01
    - Saves the combined cleaned DataFrame to CSV
    
    Args:
        file_paths: list of CSV file paths to read
        output_path: path to save the final CSV
    
    Returns:
        A single pandas DataFrame with columns ['topic_title', 'date', 'content']
    """
    dfs = []

    for path in tqdm(file_paths, desc="Processing F319 post files"):
        df = pd.read_csv(path, encoding="utf-8", dtype=str, usecols=['topic_title', 'post_time', 'content'])
        
        # Drop rows with missing essential columns
        df = df.dropna(subset=['topic_title', 'post_time', 'content'])

        # Convert post_time to datetime
        df['date'] = pd.to_datetime(df['post_time'].str.split(',').str[0], format='%d/%m/%Y', errors='coerce')
        df = df.drop(columns=['post_time'])
        

        df['content'] = df['content'].apply(clean_reply)

        dfs.append(df)

    # Combine all files into a single DataFrame
    combined_df = pd.concat(dfs, ignore_index=True)

    # Filter out posts before 2020-01-01
    combined_df = combined_df[combined_df['date'] > pd.Timestamp("2020-01-01")]

    # Make sure output directory exists
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    # Save to CSV
    combined_df.to_csv(output_path, index=False)
    print(f"Saved aggregated posts to '{output_path}'")
    print(f"Total posts after filtering: {len(combined_df)}")

    return combined_df

# %%
file_paths = [f'f319_data/posts_{i:04d}.csv' for i in range(1, 514)]
preprocess_f319_posts(file_paths)
# Out:
# Processing F319 post files: 100%|██████████| 513/513 [00:48<00:00, 10.65it/s]
# Saved aggregated posts to 'f319_data/aggregated_f319_data/aggregated_f319_posts.csv'
# Total posts after filtering: 5457935
#                                                topic_title  \
# 0        Lạm phát và thị trường chứng khoán, mối liên h...
# 1        Lạm phát và thị trường chứng khoán, mối liên h...
# 2             CỔ PHIẾU HLC – “VIÊN NGỌC ẨN” CỦA NGÀNH THAN
# 3             CỔ PHIẾU HLC – “VIÊN NGỌC ẨN” CỦA NGÀNH THAN
# 4             CỔ PHIẾU HLC – “VIÊN NGỌC ẨN” CỦA NGÀNH THAN
# ...                                                    ...
# 5915629                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5915630                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5915631                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5915632                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5915633                Triệu tập Hội Đồng Gió Mát - Tập 03
#
#                                                    content       date
# 0        (Dữ liệu: thị trường Mỹ, 1926 - 2002. Hình từ ... 2025-10-26
# 1        Mới bơm tiền vài tháng. Ăn thua đ gì mà lo sớm... 2025-10-26
# 2        Công ty Cổ phần Than Hà Lầm – Vinacomin (\nHNX... 2025-10-23
# 3        HLC quả rẻ bác, năm nay lãi to chia cổ tức tiề... 2025-10-24
# 4                                           Vãi, sàn luôn. 2025-10-24
# ...                                                    ...        ...
# 5915629  Inbox gì mén\n--- Gộp bài viết,\n17/01/2020\n-... 2020-01-17
# 5915630             Đâu rồi hội đồng của những ngày xưa cũ 2020-01-20
# 5915631  Năm nay nghỉ TET dài dài chút nhẩy các lão....... 2020-01-31
# 5915632                             Tổng múc thôi hội đồng 2020-01-31
# 5915633  Khai xuân ATC hôm nay rồi em. Mấy ae ôm hàng h... 2020-01-31
#
# [5457935 rows x 3 columns]

# %% [markdown]
# ## Load aggregated file for summarization

# %%
import pandas as pd
df = pd.read_csv("f319_data/aggregated_f319_data/aggregated_f319_posts.csv")

# %%
df
# Out:
#                                                topic_title  \
# 0        Lạm phát và thị trường chứng khoán, mối liên h...
# 1        Lạm phát và thị trường chứng khoán, mối liên h...
# 2             CỔ PHIẾU HLC – “VIÊN NGỌC ẨN” CỦA NGÀNH THAN
# 3             CỔ PHIẾU HLC – “VIÊN NGỌC ẨN” CỦA NGÀNH THAN
# 4             CỔ PHIẾU HLC – “VIÊN NGỌC ẨN” CỦA NGÀNH THAN
# ...                                                    ...
# 5457930                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457931                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457932                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457933                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457934                Triệu tập Hội Đồng Gió Mát - Tập 03
#
#                                                    content        date
# 0        (Dữ liệu: thị trường Mỹ, 1926 - 2002. Hình từ ...  2025-10-26
# 1        Mới bơm tiền vài tháng. Ăn thua đ gì mà lo sớm...  2025-10-26
# 2        Công ty Cổ phần Than Hà Lầm – Vinacomin (\nHNX...  2025-10-23
# 3        HLC quả rẻ bác, năm nay lãi to chia cổ tức tiề...  2025-10-24
# 4                                           Vãi, sàn luôn.  2025-10-24
# ...                                                    ...         ...
# 5457930  Inbox gì mén\n--- Gộp bài viết,\n17/01/2020\n-...  2020-01-17
# 5457931             Đâu rồi hội đồng của những ngày xưa cũ  2020-01-20
# 5457932  Năm nay nghỉ TET dài dài chút nhẩy các lão.......  2020-01-31
# 5457933                             Tổng múc thôi hội đồng  2020-01-31
# 5457934  Khai xuân ATC hôm nay rồi em. Mấy ae ôm hàng h...  2020-01-31
#
# [5457935 rows x 3 columns]

# %% [markdown]
# ## Get 100 most popular stock symbols in Fireant

# %%
stocks_df = pd.read_csv("fireant_data/sentiment_posts/sentiment_posts_count.csv")

# Count the total number of posts for each stock
post_counts = stocks_df.groupby('taggedSymbols').agg(
    total_posts=('total_posts', 'sum') 
).reset_index() 

# sort the stocks by total_posts in descending order
sorted_stocks = post_counts.sort_values(by='total_posts', ascending=False).reset_index(drop=True)
# get the list of 100 most mentioned stocks
top_100_stocks = sorted_stocks.head(100)['taggedSymbols'].tolist()
print(top_100_stocks)
# Out:
# ['VNINDEX', 'DIG', 'VN30F1M', 'HPG', 'VND', 'SSI', 'NVL', 'CEO', 'VIX', 'DXG', 'VIC', 'HAG', 'HSG', 'SHB', 'GEX', 'VN30', 'PDR', 'NKG', 'SHS', 'BSR', 'MBB', 'STB', 'VHM', 'CII', 'FPT', 'KBC', 'MWG', 'HCM', '^DJI', 'BCG', 'POW', 'VCI', 'VPB', 'VCG', 'PVD', 'TCB', 'HQC', 'HHV', 'DGC', 'LDG', 'TCH', 'CTG', 'DCM', 'PVS', 'TPB', 'MSN', 'DBC', 'VRE', 'FLC', 'HAH', 'DPM', 'NLG', 'VNM', 'FTS', 'MSB', 'ACB', 'MBS', 'ITA', 'LCG', 'HDC', 'FRT', 'SCR', 'ORS', 'DGW', 'LPB', 'IDC', 'EIB', 'KHG', 'GVR', 'HNG', 'HBC', 'VOS', 'EVF', 'ANV', 'HUT', 'VCB', 'IDI', 'BID', 'HPX', 'HVN', 'SZC', 'PVT', 'VSC', 'VHC', 'CTD', 'HDG', 'ROS', 'TNG', 'ASM', 'APS', 'PC1', 'FCN', 'IDJ', 'FIT', 'GMD', 'DLG', '$BTC', 'VGI', 'VGC', 'CTS']

# %% [markdown]
# ## Check Relations between Symbols and Topic Titles

# %%
import re

# create a regex pattern to match whole words only
pattern = r'\b(?:' + '|'.join(re.escape(s) for s in top_100_stocks) + r')\b'
regex = re.compile(pattern, re.IGNORECASE)

def extract_mentioned_symbols_regex(row):
    text = str(row['topic_title']) + ' ' + str(row['content'])
    matches = regex.findall(text)
    # normalize to uppercase and remove duplicates
    return list(set(match.upper() for match in matches))

# test function
extract_mentioned_symbols_regex(df.iloc[8921])
# Out:
# []

# %%
df['mentionedSymbols'] = df.apply(extract_mentioned_symbols_regex, axis=1)

# %%
df = df[df['mentionedSymbols'].apply(lambda x: isinstance(x, list) and len(x) > 0)]
df
# Out:
#                                                topic_title  \
# 12                    Chuẩn bị lên tầu đón siêu sóng Noel!
# 18                    Chuẩn bị lên tầu đón siêu sóng Noel!
# 26       Cổ phiếu sạch nhất ngành BĐS nhưng sau 8 năm, ...
# 32                                 MBB, Bank dẫn sóng....!
# 33                                 MBB, Bank dẫn sóng....!
# ...                                                    ...
# 5457873  Tuyển tập cổ phiếu có thể tăng >100% khi ra ti...
# 5457885                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457893                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457914                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457919                Triệu tập Hội Đồng Gió Mát - Tập 03
#
#                                                    content        date  \
# 12       Sau 1 thời gian tạm nghỉ có nhắn nhủ AE tại\nh...  2025-10-26
# 18                        Nhóm P thì sao bác? GÁS PVS PVD?  2025-10-26
# 26       Mình đã viết những dòng nhận xét\ncách đây 8 n...  2025-10-26
# 32       Hiệu quả – Bền vững – Tiên phong: Dấu ấn MB 9 ...  2025-10-26
# 33                              Quá rẻ so gới giá trị thật  2025-10-26
# ...                                                    ...         ...
# 5457873  Ctd mua lệnh quét không cần kê lệnh. Tay to hố...  2020-01-22
# 5457885  Uh, hồi xưa em chỉ múc pvd\n, giờ chuyển cv mú...  2020-01-02
# 5457893  Ngon cc. Cuối năm chả hú rộn cả lên múc CTG cò...  2020-01-02
# 5457914  lão nói vậy không hẳn đúng đâu, ôm NKG là có c...  2020-01-16
# 5457919                                  đói CL mai hsg ce  2020-01-16
#
#         mentionedSymbols
# 12        [VNINDEX, VCI]
# 18            [PVD, PVS]
# 26                 [NLG]
# 32                 [MBB]
# 33                 [MBB]
# ...                  ...
# 5457873            [CTD]
# 5457885            [PVD]
# 5457893            [CTG]
# 5457914            [NKG]
# 5457919            [HSG]
#
# [2163562 rows x 4 columns]

# %%
# Save for future use
df.to_csv('f319_data/aggregated_f319_data/aggregated_f319_posts_with_symbols.csv', index=False)

# %%
df.iloc[1]['content']
# Out:
# 'Nhóm P thì sao bác? GÁS PVS PVD?'

# %% [markdown]
# ## Posts Cleaning

# %%
import re

def remove_links(text):
    # Xóa link dạng http(s)://... hoặc www....
    text = re.sub(r"http\S+", "", text)     # remove http:// hoặc https://
    text = re.sub(r"www\.\S+", "", text)    # remove www...
    text = re.sub(r"\S+\.com\S*", "", text) # remove .com/.net/.vn...
    return text.strip()

def clean_text(text):
    text = str(text).lower()                          # lowercase
    text = re.sub(r"\n+", ". ", text)                # replace new line with period
    text = remove_links(text)                         # remove links
    text = re.sub(r"@\w+", "", text)                  # remove mentions (@abc)
    text = re.sub(r"#\w+", "", text)                  # remove hashtags
    text = re.sub(
        r"[^0-9a-zA-Záàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệ"
        r"íìỉĩịóòỏõọôốồổỗộơớờởỡợúùủũụưứừửữự"
        r"ýỳỷỹỵđ\s!?,.]+", 
        " ", 
        text
    )            # keep only letters, numbers and some punctuation
    text = re.sub(r"\s+", " ", text).strip()          # remove extra spaces
    return text

# %%
df['content'] = df['content'].apply(clean_text)
df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1768\1649223096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content'] = df['content'].apply(clean_text)
#                                                topic_title  \
# 12                    Chuẩn bị lên tầu đón siêu sóng Noel!
# 18                    Chuẩn bị lên tầu đón siêu sóng Noel!
# 26       Cổ phiếu sạch nhất ngành BĐS nhưng sau 8 năm, ...
# 32                                 MBB, Bank dẫn sóng....!
# 33                                 MBB, Bank dẫn sóng....!
# ...                                                    ...
# 5457873  Tuyển tập cổ phiếu có thể tăng >100% khi ra ti...
# 5457885                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457893                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457914                Triệu tập Hội Đồng Gió Mát - Tập 03
# 5457919                Triệu tập Hội Đồng Gió Mát - Tập 03
#
#                                                    content        date  \
# 12       sau 1 thời gian tạm nghỉ có nhắn nhủ ae tại. t...  2025-10-26
# 18                        nhóm p thì sao bác? gás pvs pvd?  2025-10-26
# 26       mình đã viết những dòng nhận xét. cách đây 8 n...  2025-10-26
# 32       hiệu quả bền vững tiên phong dấu ấn mb 9 tháng...  2025-10-26
# 33                              quá rẻ so gới giá trị thật  2025-10-26
# ...                                                    ...         ...
# 5457873  ctd mua lệnh quét không cần kê lệnh. tay to hố...  2020-01-22
# 5457885  uh, hồi xưa em chỉ múc pvd. , giờ chuyển cv mú...  2020-01-02
# 5457893  ngon cc. cuối năm chả hú rộn cả lên múc ctg cò...  2020-01-02
# 5457914  lão nói vậy không hẳn đúng đâu, ôm nkg là có c...  2020-01-16
# 5457919                                  đói cl mai hsg ce  2020-01-16
#
#         mentionedSymbols
# 12        [VNINDEX, VCI]
# 18            [PVD, PVS]
# 26                 [NLG]
# 32                 [MBB]
# 33                 [MBB]
# ...                  ...
# 5457873            [CTD]
# 5457885            [PVD]
# 5457893            [CTG]
# 5457914            [NKG]
# 5457919            [HSG]
#
# [2163562 rows x 4 columns]

# %%
# remove duplicates in content column
print(f"Number of posts before removing duplicates: {len(df)}")
df = df.drop_duplicates(subset=['content'])
print(f"Number of posts after removing duplicates: {len(df)}")

# reset index 
df = df.reset_index(drop=True)
df
# Out:
# Number of posts before removing duplicates: 2163562
# Number of posts after removing duplicates: 2076873
#                                                topic_title  \
# 0                     Chuẩn bị lên tầu đón siêu sóng Noel!
# 1                     Chuẩn bị lên tầu đón siêu sóng Noel!
# 2        Cổ phiếu sạch nhất ngành BĐS nhưng sau 8 năm, ...
# 3                                  MBB, Bank dẫn sóng....!
# 4                                  MBB, Bank dẫn sóng....!
# ...                                                    ...
# 2076868  Tuyển tập cổ phiếu có thể tăng >100% khi ra ti...
# 2076869                Triệu tập Hội Đồng Gió Mát - Tập 03
# 2076870                Triệu tập Hội Đồng Gió Mát - Tập 03
# 2076871                Triệu tập Hội Đồng Gió Mát - Tập 03
# 2076872                Triệu tập Hội Đồng Gió Mát - Tập 03
#
#                                                    content        date  \
# 0        sau 1 thời gian tạm nghỉ có nhắn nhủ ae tại. t...  2025-10-26
# 1                         nhóm p thì sao bác? gás pvs pvd?  2025-10-26
# 2        mình đã viết những dòng nhận xét. cách đây 8 n...  2025-10-26
# 3        hiệu quả bền vững tiên phong dấu ấn mb 9 tháng...  2025-10-26
# 4                               quá rẻ so gới giá trị thật  2025-10-26
# ...                                                    ...         ...
# 2076868  ctd mua lệnh quét không cần kê lệnh. tay to hố...  2020-01-22
# 2076869  uh, hồi xưa em chỉ múc pvd. , giờ chuyển cv mú...  2020-01-02
# 2076870  ngon cc. cuối năm chả hú rộn cả lên múc ctg cò...  2020-01-02
# 2076871  lão nói vậy không hẳn đúng đâu, ôm nkg là có c...  2020-01-16
# 2076872                                  đói cl mai hsg ce  2020-01-16
#
#         mentionedSymbols
# 0         [VNINDEX, VCI]
# 1             [PVD, PVS]
# 2                  [NLG]
# 3                  [MBB]
# 4                  [MBB]
# ...                  ...
# 2076868            [CTD]
# 2076869            [PVD]
# 2076870            [CTG]
# 2076871            [NKG]
# 2076872            [HSG]
#
# [2076873 rows x 4 columns]

# %%
df.iloc[1]['content']
# Out:
# 'nhóm p thì sao bác? gás pvs pvd?'

# %% [markdown]
# ## Sentiment Analysis

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from tqdm.auto import tqdm

# Load model
model_path = "Sentiment Model"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)

# Automatically use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()


# ------------------------------------
#  Single text prediction
# ------------------------------------
def predict_sentiment(text):
    inputs = tokenizer(
        text,
        truncation=True,
        padding=True,
        max_length=256,
        return_tensors="pt"
    ).to(device)

    with torch.no_grad():
        logits = model(**inputs).logits
        pred = torch.argmax(logits, dim=1).item()

    return pred

def predict_batch(text_list, batch_size=32):
    preds = []
    
    for i in tqdm(range(0, len(text_list), batch_size), desc="Predicting"):
        batch = text_list[i : i + batch_size]

        inputs = tokenizer(
            batch,
            truncation=True,
            padding=True,
            max_length=256,
            return_tensors="pt"
        ).to(device)

        with torch.no_grad():
            logits = model(**inputs).logits
            batch_preds = torch.argmax(logits, dim=1).cpu().tolist()
            preds.extend(batch_preds)

    return preds

# %%
# Convert the column to a list
texts = df["content"].astype(str).tolist()

# Run batch prediction
preds = predict_batch(texts, batch_size=32)

# Assign results back to df
df["sentiment"] = preds
# Out:
# Predicting: 100%|██████████| 64903/64903 [7:28:25<00:00,  2.41it/s]

# %%
# count number rows with sentiment = 0
df[df['sentiment'] == 1].head(30)
# Out:
#                                           topic_title  \
# 0                Chuẩn bị lên tầu đón siêu sóng Noel!
# 1                Chuẩn bị lên tầu đón siêu sóng Noel!
# 2   Cổ phiếu sạch nhất ngành BĐS nhưng sau 8 năm, ...
# 3                             MBB, Bank dẫn sóng....!
# 4                             MBB, Bank dẫn sóng....!
# 5                             MBB, Bank dẫn sóng....!
# 6                             MBB, Bank dẫn sóng....!
# 8                             MBB, Bank dẫn sóng....!
# 9                             MBB, Bank dẫn sóng....!
# 10                            MBB, Bank dẫn sóng....!
# 12                            MBB, Bank dẫn sóng....!
# 15                            MBB, Bank dẫn sóng....!
# 16                            MBB, Bank dẫn sóng....!
# 17                            MBB, Bank dẫn sóng....!
# 19  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 21  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 22  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 23  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 26  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 27  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 28  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 29  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 30  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 31  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 32  Doanh thu tối thiểu quý 4 2025 SZC gấp 3 lần. ...
# 33  KHG - Khúc Khải Hoàn Ca trong Kỷ nguyên vươn mình
# 34  KHG - Khúc Khải Hoàn Ca trong Kỷ nguyên vươn mình
# 35                      NTC - một kèo đầu tư cực chất
# 36                   APF - Cơ hội tích sản khi PB = 1
# 37                   APF - Cơ hội tích sản khi PB = 1
#
#                                               content        date  \
# 0   sau 1 thời gian tạm nghỉ có nhắn nhủ ae tại. t...  2025-10-26
# 1                    nhóm p thì sao bác? gás pvs pvd?  2025-10-26
# 2   mình đã viết những dòng nhận xét. cách đây 8 n...  2025-10-26
# 3   hiệu quả bền vững tiên phong dấu ấn mb 9 tháng...  2025-10-26
# 4                          quá rẻ so gới giá trị thật  2025-10-26
# 5            giá cao quá, tây bán rát, về thấp nữa đi  2025-10-26
# 6   ko bank nào phát triển mạnh mẽ bằng mbb đâu. c...  2025-10-26
# 8   ai đã bán mbb giá 27 28k, canh mua lại giá qua...  2025-10-26
# 9                                  mbb ngon quá ae ơi  2025-10-26
# 10  lợi nhuận tăng dc 12 nhưng giá đã tăng mịa nó ...  2025-10-26
# 12  mbb là 1 cổ phiếu tăng trưởng tốt. nền móng vữ...  2025-10-26
# 15               phiên mai mbb mà có giá đỏ thì tuyệt  2025-10-26
# 16                          tây múc tpb ! mục tiêu 25  2025-10-26
# 17  4.11 là ngày kỷ niệm 31 năm mb. thấy ngày 1.11...  2025-10-26
# 19  lợi nhuận szc thấp nhất 10 quý, doanh thu kcn ...  2025-10-26
# 21  thứ 2 chú ý cặp ntc sip ... khả năng mạnh của ...  2025-10-26
# 22  bác phân tích kĩ hơn giúp em xíu, ntc sip liên...  2025-10-26
# 23  vn thì cứ diễn trò, book lợi nhuận cao xả, boo...  2025-10-26
# 26  cái đó là quá khứ rồi bác. quan trọng bây giờ ...  2025-10-26
# 27  thì đáy gồi chứ sao pác, múc đi, tui mới múc i...  2025-10-26
# 28  szc giá mua trung hạn đẹp nhất tầm 20 22 idc t...  2025-10-26
# 29                  bác đang tính giá sau chia tách à  2025-10-26
# 30  hô cho vui, ko có cửa xuống đó. gộp bài viết,....  2025-10-26
# 31                          thứ 3 nhỉ, tính nhầm ngày  2025-10-26
# 32  vậy ntc sẽ là cảm hứng để anh em bđs kcn tăng ...  2025-10-26
# 33  1. chuyển mình từ nhà môi giới tới nhà đầu tư ...  2025-10-26
# 34  phân tích thêm cái đồ thị kĩ thuật nữa là chuẩ...  2025-10-26
# 35  ctcp khu công nghiệp nam tân uyên ntc sẽ chuyể...  2025-10-26
# 36  apf sản xuất ra sản phẩm gì?. 1 tinh bột sắn t...  2025-10-07
# 37  cồn của apf là cồn thực phẩm, y tế giá cao hơn...  2025-10-22
#
#    mentionedSymbols  sentiment
# 0    [VNINDEX, VCI]          1
# 1        [PVD, PVS]          1
# 2             [NLG]          1
# 3             [MBB]          1
# 4             [MBB]          1
# 5             [MBB]          1
# 6             [MBB]          1
# 8             [MBB]          1
# 9             [MBB]          1
# 10            [MBB]          1
# 12            [MBB]          1
# 15            [MBB]          1
# 16       [TPB, MBB]          1
# 17            [MBB]          1
# 19            [SZC]          1
# 21       [GEX, SZC]          1
# 22       [GEX, SZC]          1
# 23            [SZC]          1
# 26            [SZC]          1
# 27       [SZC, IDC]          1
# 28       [SZC, IDC]          1
# 29            [SZC]          1
# 30       [GEX, SZC]          1
# 31            [SZC]          1
# 32            [SZC]          1
# 33       [KHG, VND]          1
# 34            [KHG]          1
# 35       [HCM, IDC]          1
# 36            [CEO]          1
# 37            [DGC]          1

# %%
df.to_csv('f319_data/aggregated_f319_data/aggregated_f319_posts_with_symbols_and_sentiment.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('f319_data/aggregated_f319_data/aggregated_f319_posts_with_symbols_and_sentiment.csv')
df
# Out:
#                                                topic_title  \
# 0                     Chuẩn bị lên tầu đón siêu sóng Noel!
# 1                     Chuẩn bị lên tầu đón siêu sóng Noel!
# 2        Cổ phiếu sạch nhất ngành BĐS nhưng sau 8 năm, ...
# 3                                  MBB, Bank dẫn sóng....!
# 4                                  MBB, Bank dẫn sóng....!
# ...                                                    ...
# 2076868  Tuyển tập cổ phiếu có thể tăng >100% khi ra ti...
# 2076869                Triệu tập Hội Đồng Gió Mát - Tập 03
# 2076870                Triệu tập Hội Đồng Gió Mát - Tập 03
# 2076871                Triệu tập Hội Đồng Gió Mát - Tập 03
# 2076872                Triệu tập Hội Đồng Gió Mát - Tập 03
#
#                                                    content        date  \
# 0        sau 1 thời gian tạm nghỉ có nhắn nhủ ae tại. t...  2025-10-26
# 1                         nhóm p thì sao bác? gás pvs pvd?  2025-10-26
# 2        mình đã viết những dòng nhận xét. cách đây 8 n...  2025-10-26
# 3        hiệu quả bền vững tiên phong dấu ấn mb 9 tháng...  2025-10-26
# 4                               quá rẻ so gới giá trị thật  2025-10-26
# ...                                                    ...         ...
# 2076868  ctd mua lệnh quét không cần kê lệnh. tay to hố...  2020-01-22
# 2076869  uh, hồi xưa em chỉ múc pvd. , giờ chuyển cv mú...  2020-01-02
# 2076870  ngon cc. cuối năm chả hú rộn cả lên múc ctg cò...  2020-01-02
# 2076871  lão nói vậy không hẳn đúng đâu, ôm nkg là có c...  2020-01-16
# 2076872                                  đói cl mai hsg ce  2020-01-16
#
#            mentionedSymbols  sentiment
# 0        ['VNINDEX', 'VCI']          1
# 1            ['PVD', 'PVS']          1
# 2                   ['NLG']          1
# 3                   ['MBB']          1
# 4                   ['MBB']          1
# ...                     ...        ...
# 2076868             ['CTD']          1
# 2076869             ['PVD']          1
# 2076870             ['CTG']          1
# 2076871             ['NKG']          0
# 2076872             ['HSG']          1
#
# [2076873 rows x 5 columns]

# %%
# drop columns 'topic_title' and 'content'
df = df.drop(columns=['topic_title', 'content'])
df
# Out:
#                date    mentionedSymbols  sentiment
# 0        2025-10-26  ['VNINDEX', 'VCI']          1
# 1        2025-10-26      ['PVD', 'PVS']          1
# 2        2025-10-26             ['NLG']          1
# 3        2025-10-26             ['MBB']          1
# 4        2025-10-26             ['MBB']          1
# ...             ...                 ...        ...
# 2076868  2020-01-22             ['CTD']          1
# 2076869  2020-01-02             ['PVD']          1
# 2076870  2020-01-02             ['CTG']          1
# 2076871  2020-01-16             ['NKG']          0
# 2076872  2020-01-16             ['HSG']          1
#
# [2076873 rows x 3 columns]

# %%
# Explode the 'mentionedSymbols' column
df['mentionedSymbols'] = df['mentionedSymbols'].apply(lambda x: eval(x) if isinstance(x, str) else [])
df = df.explode('mentionedSymbols').reset_index(drop=True)
df
# Out:
#                date mentionedSymbols  sentiment
# 0        2025-10-26          VNINDEX          1
# 1        2025-10-26              VCI          1
# 2        2025-10-26              PVD          1
# 3        2025-10-26              PVS          1
# 4        2025-10-26              NLG          1
# ...             ...              ...        ...
# 2955196  2020-01-22              CTD          1
# 2955197  2020-01-02              PVD          1
# 2955198  2020-01-02              CTG          1
# 2955199  2020-01-16              NKG          0
# 2955200  2020-01-16              HSG          1
#
# [2955201 rows x 3 columns]

# %%
# group by date and mentionedSymbols
df_grouped = df.groupby(['date', 'mentionedSymbols']).agg(
    total_posts=('sentiment', 'count'),
    positive_posts=('sentiment', lambda x: (x == 1).sum()),
    negative_posts=('sentiment', lambda x: (x == 0).sum()),
).reset_index()

df_grouped
# Out:
#               date mentionedSymbols  total_posts  positive_posts  \
# 0       2020-01-02              ACB            3               1
# 1       2020-01-02              ASM            2               1
# 2       2020-01-02              BCG            2               0
# 3       2020-01-02              BID           42              33
# 4       2020-01-02              BSR            3               3
# ...            ...              ...          ...             ...
# 168041  2025-10-26             VN30            4               4
# 168042  2025-10-26              VND            9               8
# 168043  2025-10-26          VNINDEX           17              16
# 168044  2025-10-26              VNM            1               1
# 168045  2025-10-26              VPB            5               1
#
#         negative_posts
# 0                    2
# 1                    1
# 2                    2
# 3                    9
# 4                    0
# ...                ...
# 168041               0
# 168042               1
# 168043               1
# 168044               0
# 168045               4
#
# [168046 rows x 5 columns]

# %%
df_grouped.to_csv('f319_data/aggregated_f319_data/sentiment_summary_by_stock_and_date.csv', index=False)
